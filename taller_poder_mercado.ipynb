# %% [markdown]
# <a href="https://colab.research.google.com/github/Davichobacter/ds-4geeks/blob/main/taller_poder_mercado.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Recuerde que en una situacion de maximizacion se busca la mayor diferencia entre los ingresos totales y los
# costos es decir maximizar π(q):

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy

# %%
url = ('https://raw.githubusercontent.com/it-ces/Datasets/refs/heads/main/MarketPower.csv')

# %%
df = pd.read_csv(url)
df
# Out:
#      Unnamed: 0        theta  beta         cm     sector
# 0             0   125.121419  31.5   9.799712   Software
# 1             1   125.645324  30.5  10.616998   Software
# 2             2   126.766324  17.5   9.426922   Software
# 3             3   127.141536  22.5   9.698818   Software
# 4             4   127.472341  28.5   9.042124   Software
# ..          ...          ...   ...        ...        ...
# 122           0  1237.516764  24.4   4.306088  Financial
# 123           1  1236.938396  11.4   5.101223  Financial
# 124           2  1235.802773  12.4   4.073056  Financial
# 125           3  1237.271186  23.4   3.709515  Financial
# 126           4  1238.975302  30.4   6.014435  Financial
#
# [127 rows x 5 columns]

# %%
df.rename(columns={'Unnamed: 0': 'ID'}, inplace=True)
df
# Out:
#      ID        theta  beta         cm     sector
# 0     0   125.121419  31.5   9.799712   Software
# 1     1   125.645324  30.5  10.616998   Software
# 2     2   126.766324  17.5   9.426922   Software
# 3     3   127.141536  22.5   9.698818   Software
# 4     4   127.472341  28.5   9.042124   Software
# ..   ..          ...   ...        ...        ...
# 122   0  1237.516764  24.4   4.306088  Financial
# 123   1  1236.938396  11.4   5.101223  Financial
# 124   2  1235.802773  12.4   4.073056  Financial
# 125   3  1237.271186  23.4   3.709515  Financial
# 126   4  1238.975302  30.4   6.014435  Financial
#
# [127 rows x 5 columns]

# %% [markdown]
# Para el siguiente ejercicio consulte la base de datos Disponible aqu´ı: Asuma que la empresa i tiene la siguiente
# funci´on de ingreso marginal y los par´ametros estimados θ y β siendo entonces βi el par´ametro para la empresa
# i.
# $$ IMi = θi − 2βiq $$
# determine cuales son los niveles optimos de producci´on para cada empresa si dentro de la base de datos est´a la
# informaci´on de los costos marginales ( asuma que son constantes).

# %%
df['ingreso_marginal'] = df['theta'] - 2*df['beta']
df
# Out:
#      ID        theta  beta         cm     sector  ingreso_marginal
# 0     0   125.121419  31.5   9.799712   Software         62.121419
# 1     1   125.645324  30.5  10.616998   Software         64.645324
# 2     2   126.766324  17.5   9.426922   Software         91.766324
# 3     3   127.141536  22.5   9.698818   Software         82.141536
# 4     4   127.472341  28.5   9.042124   Software         70.472341
# ..   ..          ...   ...        ...        ...               ...
# 122   0  1237.516764  24.4   4.306088  Financial       1188.716764
# 123   1  1236.938396  11.4   5.101223  Financial       1214.138396
# 124   2  1235.802773  12.4   4.073056  Financial       1211.002773
# 125   3  1237.271186  23.4   3.709515  Financial       1190.471186
# 126   4  1238.975302  30.4   6.014435  Financial       1178.175302
#
# [127 rows x 6 columns]

# %%
df['demanda_optima'] = (df['theta'] - df['cm'])/(df['beta']*2)
df
# Out:
#      ID        theta  beta         cm     sector  ingreso_marginal  \
# 0     0   125.121419  31.5   9.799712   Software         62.121419
# 1     1   125.645324  30.5  10.616998   Software         64.645324
# 2     2   126.766324  17.5   9.426922   Software         91.766324
# 3     3   127.141536  22.5   9.698818   Software         82.141536
# 4     4   127.472341  28.5   9.042124   Software         70.472341
# ..   ..          ...   ...        ...        ...               ...
# 122   0  1237.516764  24.4   4.306088  Financial       1188.716764
# 123   1  1236.938396  11.4   5.101223  Financial       1214.138396
# 124   2  1235.802773  12.4   4.073056  Financial       1211.002773
# 125   3  1237.271186  23.4   3.709515  Financial       1190.471186
# 126   4  1238.975302  30.4   6.014435  Financial       1178.175302
#
#      demanda_optima
# 0          1.830503
# 1          1.885710
# 2          3.352554
# 3          2.609838
# 4          2.077723
# ..              ...
# ...

# %%
df_grupo = df.groupby(['sector', 'ID']).sum()
df_grupo
# Out:
#                      theta  beta         cm  ingreso_marginal  demanda_optima
# sector      ID
# Agriculture 0   804.022920  13.4   5.373018        777.222920       29.800369
#             1   802.589625  19.4   5.147825        763.789625       20.552624
#             2   802.753187  22.4   5.223327        757.953187       17.802006
#             3   802.640364   5.4   4.619689        791.840364       73.890803
#             4   801.769385  10.4   7.762560        780.969385       38.173405
# ...                    ...   ...        ...               ...             ...
# Software    15  126.363042  27.5  10.906843         71.363042        2.099204
#             16  124.345453  25.5   9.300229         73.345453        2.255789
#             17  125.344074  28.5  10.950832         68.344074        2.006899
#             18  126.083198  12.5  11.637646        101.083198        4.577822
#             19  127.708055  26.5   8.819338         74.708055        2.243183
#
# ...

# %%
df_grupo['demanda_total'] = df_grupo.groupby('sector')['demanda_optima'].transform('sum')
df_grupo
# Out:
#                      theta  beta         cm  ingreso_marginal  demanda_optima  \
# sector      ID
# Agriculture 0   804.022920  13.4   5.373018        777.222920       29.800369
#             1   802.589625  19.4   5.147825        763.789625       20.552624
#             2   802.753187  22.4   5.223327        757.953187       17.802006
#             3   802.640364   5.4   4.619689        791.840364       73.890803
#             4   801.769385  10.4   7.762560        780.969385       38.173405
# ...                    ...   ...        ...               ...             ...
# Software    15  126.363042  27.5  10.906843         71.363042        2.099204
#             16  124.345453  25.5   9.300229         73.345453        2.255789
#             17  125.344074  28.5  10.950832         68.344074        2.006899
#             18  126.083198  12.5  11.637646        101.083198        4.577822
#             19  127.708055  26.5   8.819338         74.708055        2.243183
#
# ...

# %%
df_grupo['porcentaje_participacion'] = (df_grupo['demanda_optima'] / df_grupo.groupby('sector')['demanda_optima'].transform('sum'))*100
df_grupo
# Out:
#                      theta  beta         cm  ingreso_marginal  demanda_optima  \
# sector      ID
# Agriculture 0   804.022920  13.4   5.373018        777.222920       29.800369
#             1   802.589625  19.4   5.147825        763.789625       20.552624
#             2   802.753187  22.4   5.223327        757.953187       17.802006
#             3   802.640364   5.4   4.619689        791.840364       73.890803
#             4   801.769385  10.4   7.762560        780.969385       38.173405
# ...                    ...   ...        ...               ...             ...
# Software    15  126.363042  27.5  10.906843         71.363042        2.099204
#             16  124.345453  25.5   9.300229         73.345453        2.255789
#             17  125.344074  28.5  10.950832         68.344074        2.006899
#             18  126.083198  12.5  11.637646        101.083198        4.577822
#             19  127.708055  26.5   8.819338         74.708055        2.243183
#
# ...

# %%
df_grupo[df_grupo.index.get_level_values('sector') == 'Diapers']
# Out:
#                   theta  beta        cm  ingreso_marginal  demanda_optima  \
# sector  ID
# Diapers 0   9004.596285  10.0  4.436117       8984.596285      450.008008
#         1   9002.209441  29.0  4.209153       8944.209441      155.137936
#
#             porcentaje_participacion
# sector  ID
# Diapers 0                   74.36355
#         1                   25.63645

# %%
sectores = df['sector'].unique()

for sector in sectores:
